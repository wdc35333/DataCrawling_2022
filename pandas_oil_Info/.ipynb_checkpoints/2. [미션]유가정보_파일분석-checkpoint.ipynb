# %% [markdown]
# ### 코랩에서 한글 사용하기
# - 한글 글꼴 설치 => [런타임]-[런타임 다시 시작] 클릭

# %% [markdown]
# ### 서울시 유가정보(11개 구) 분서

# %% [markdown]
# #### [미션1] 서울시 유가정보 가져와 1개로 합치기
# 1. "/content" 폴더에 "data" 폴더 생성후 파일 업로드
# 2. data 폴더에 있는 데이터 읽어와 oildf에 모두 저장
# 3. 데이터는 concat()을 이용해 데이터의 아래에 추가
# 4. encoding: cp949 또는 utf8이 같이 있어 에러 발생
#         try: ~ except: ~ 로 해결

# %% [markdown]
# - data 폴더에 있는 파일명/하위폴더명 가져오기: os모듈
# - for문을 이용 첫번째 파일부터 순차적으로 읽어와 oildf에 concat 진행
# - 파일을 읽을시 encoding 에러
#         try:
#             utf-8 형식 읽어오기
#         except:
#             cp949 형식 읽어오기
# - 빈 DataFrame 변수 생성
#         oildf=pd.DataFrame()

# %%
import pandas as pd
import os

fnames=os.listdir("./data")

oildf = pd.DataFrame()

for fname in fnames:
    try:
        df0=pd.read_csv("./data/" + fname, header=2)
    except:
        df0=pd.read_csv("./data/" + fname, header=2, encoding="cp949")
        
    oildf=pd.concat([oildf, df0])  # 옵션: ignore_index=True : index 재설정

del df0

oildf.reset_index(drop=True, inplace=True)

display(oildf.head(3))
oildf.info()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#       9 try:
# ---> 10     df0=pd.read_csv("./data/" + fname, header=2)
#      11 except:
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1231, in TextFileReader._make_engine(self, f, engine)
#    1230 try:
# -> 1231     return mapping[engine](f, **self.options)
#    1232 except Exception:
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xce in position 88: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#      10         df0=pd.read_csv("./data/" + fname, header=2)
#      11     except:
# ---> 12         df0=pd.read_csv("./data/" + fname, header=2, encoding="cp949")
#      14     oildf=pd.concat([oildf, df0])  # 옵션: ignore_index=True : index 재설정
#      16 del df0
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1231, in TextFileReader._make_engine(self, f, engine)
#    1228     f = self.handles.handle
#    1230 try:
# -> 1231     return mapping[engine](f, **self.options)
#    1232 except Exception:
#    1233     if self.handles is not None:
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xce in position 88: illegal multibyte sequence

# %% [markdown]
# #### [미션2] 데이터 전처리
# - NaN 값 포함된 데이터 전체 삭제
# - "구" 필드 생성하기
# - 데이터 출력 필드: 상호, 상표, 구, 셀프여부, 휘발유, 경우 만 출력
# - "휘발유", "경유": float64로 변경
# - "휘발유", "경유" 데이터의 "-"를 평균값으로 수정

# %%
## 필드명 NaN 갯수 확인
oildf.isna().sum()
# Out:
# 지역        0
# 상호        0
# 주소        0
# 상표        0
# 전화번호      0
# 셀프여부      0
# 고급휘발유    22
# 휘발유       5
# 경유        4
# 실내등유     36
# dtype: int64

# %%
## loc[] 함수를 이용해 주소에서 구 추출하기
gutxt = []
for i in oildf.index:
    gutxt.append( oildf.loc[i, '주소'].split(" ")[1] )

# %%
# 한줄쓰기로 표현
gutxt=[ oildf.loc[i, '주소'].split(" ")[1] for i in oildf.index ]

# %%
# iloc[] 함수를 이용해 주소에서 구 추출하기
gutxt=[ oildf.iloc[i, 2].split(" ")[1] for i in range(len(oildf)) ]

# %%
# "구" 필드 추가
oildf["구"]=gutxt

# %%
# 필드명으로 DataFrame 생성하기
oildf1=oildf[['상호','상표',"구",'셀프여부', '휘발유', '경유']]

# %%
# iloc를 이용한 DataFrame 생성하기
oildf2=oildf.iloc[:, [1, 3,-1, 5, 7, 8]]
oildf2.dtypes
# Out:
# 상호      object
# 상표      object
# 구       object
# 셀프여부    object
# 휘발유     object
# 경유      object
# dtype: object

# %%
display(oildf1.head(1))
display(oildf2.head(1))
# Out:
#        상호      상표    구 셀프여부     휘발유      경유
# 0  구천면주유소  현대오일뱅크  강동구    N  1993.0  1887.0
#        상호      상표    구 셀프여부     휘발유      경유
# 0  구천면주유소  현대오일뱅크  강동구    N  1993.0  1887.0

# %%
# NaN값 0으로 변경
oildf2=oildf2.fillna(0)

# %%
# 휘발유/경우 데이터에서 "-" 값만 찾아 0으로 변경
oildf2.loc[oildf2.휘발유=="-",'휘발유']=0
oildf2.loc[oildf2["경유"]=="-",'경유']=0

# %% [markdown]
# Index(['지역', '상호', '주소', '상표', '전화번호', '셀프여부', '고급휘발유', '휘발유', '경유', '실내등유'],

# %%
# 고유값 확인하기
oildf2['휘발유'].unique()
# Out:
# array([1993.0, 0, 2018.0, 2025.0, 2035.0, 2048.0, 2062.0, 2065.0, 2098.0,
#        2172.0, 2298.0, 1926.0, 1955.0, 1975.0, 1978.0, 1979.0, 1986.0,
#        1989.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2029.0, 2099.0,
#        2177.0, '2089', '2119', '2120', '2345', '2378', '2395', '2398',
#        '1945', '1995', '1998', '1999', '2007', '2011', '2028', '2039',
#        '2045', '2053', '2065', '2069', '2085', 1987.0, 2028.0, 2038.0,
#        2040.0, 2045.0, 2047.0, 2052.0, 2055.0, 2079.0, 2089.0, 2097.0,
#        2108.0, 2158.0, 2194.0, 2228.0, 2239.0, 2243.0, 2288.0, 2296.0,
#        2329.0, 2380.0, 2393.0, 2394.0, 2398.0, 2545.0, 2008, 2010, 2020,
#        2022, 2031, 2071, 2073, 2074, 2088, 2095, 2138, 2198, 2238, 2477,
#        1985, 1988, 2023, 2027, 2148, 2039, 2059, 2069, 2199, 2299, 1968,
#        2009, 2015, 2090, '1949', '1954', '1973', '1985', '2014', '2018',
#        '2025', '2027', '2048', '2068'], dtype=object)

# %%
# 휘발유/경우 실수형 자료로 변경하기
oildf2=oildf2.astype({"휘발유":float, "경유":float})
oildf2.dtypes  # 데이터 타입 확인하기
# Out:
# 상호       object
# 상표       object
# 구        object
# 셀프여부     object
# 휘발유     float64
# 경유      float64
# dtype: object

# %%
# 휘발유/경유 데이터에서 0인 값을 평균값으로 변경하기
oildf2.loc[oildf2.휘발유 == 0,'휘발유'] = oildf2.loc[oildf2.휘발유 != 0,'휘발유'].mean()
oildf2.loc[oildf2["경유"] == 0,'경유'] = oildf2.loc[oildf2["경유"] != 0,'경유'].mean()

# %%
# 0인 값이 인는지 확인
oildf2.loc[oildf2["경유"] == "-", :]
# Out:
# Empty DataFrame
# Columns: [상호, 상표, 구, 셀프여부, 휘발유, 경유]
# Index: []

# %%
# oildf2에서 휘발유 최고가 검색
oildf2[oildf2["휘발유"] == oildf2["휘발유"].max()]
# Out:
#          상호      상표    구 셀프여부     휘발유      경유
# 99  제이제이주유소  현대오일뱅크  강남구    N  2545.0  2335.0

# %%
# "구" 필드를 기준으로 평균 값 계산
guGroup=oildf2.groupby(by="구").mean()   # 그룹 항목이 index로 설정
guGroup.head()
# Out:
#              휘발유           경유
# 구
# 강남구  2147.099888  2038.561369
# 강동구  2075.842660  1960.161206
# 강북구  2001.230769  1912.153846
# 노원구  2035.933333  1938.666667
# 도봉구  2020.994368  1934.792049

# %%
# 강북구 데이터만 출력
guGroup.loc[["강북구"]]
# Out:
#              휘발유           경유
# 구
# 강북구  2001.230769  1912.153846

# %%
# 강북구 / 양천구 출력
guGroup.loc[["강북구","양천구"]]
# Out:
#              휘발유           경유
# 구
# 강북구  2001.230769  1912.153846
# 양천구  2001.760000  1929.840000

# %%
guGroup.index
# Out:
# Index(['강남구', '강동구', '강북구', '노원구', '도봉구', '마포구', '서초구', '송파구', '양천구', '은평구',
#        '종로구'],
#       dtype='object', name='구')

# %%
# 강북구 ~ 서초구까지 의 휘발유값 출력
guGroup.loc["강북구":"서초구", "휘발유"]
# Out:
# 구
# 강북구    2001.230769
# 노원구    2035.933333
# 도봉구    2020.994368
# 마포구    2071.750000
# 서초구    2068.696970
# Name: 휘발유, dtype: float64

# %%
# 구별 주유소 갯수
oildf2.groupby(["구"])["상표"].count()
# Out:
# 구
# 강남구    37
# 강동구    14
# 강북구    13
# 노원구    15
# 도봉구    18
# 마포구    12
# 서초구    33
# 송파구    32
# 양천구    25
# 은평구    17
# 종로구     9
# Name: 상표, dtype: int64

# %%
# 구별/상표별 주유소 갯수
oildf2.groupby(["구", "상표"])[["휘발유", "경유"]].count()
# Out:
#             휘발유  경유
# 구   상표
# 강남구 GS칼텍스     9   9
#     SK에너지    15  15
#     SOIL      5   5
#     현대오일뱅크    8   8
# 강동구 GS칼텍스     5   5
#     S-OIL     2   2
#     SK에너지     3   3
#     현대오일뱅크    4   4
# 강북구 GS칼텍스     3   3
#     S-OIL     3   3
#     SK에너지     3   3
#     현대오일뱅크    4   4
# 노원구 GS칼텍스     6   6
#     S-OIL     3   3
#     SK에너지     3   3
#     현대오일뱅크    3   3
# 도봉구 GS칼텍스     3   3
#     S-OIL     5   5
#     SK에너지     3   3
#     현대오일뱅크    7   7
# 마포구 GS칼텍스     1   1
#     S-OIL     3   3
#     SK에너지     5   5
#     현대오일뱅크    3   3
# 서초구 GS칼텍스    13  13
#     S-OIL     5   5
#     SK에너지     9   9
#     알뜰(ex)    1   1
#     현대오일뱅크    5   5
# 송파구 GS칼텍스     9   9
#     S-OIL     5   5
#     SK에너지    10  10
#     현대오일뱅크    8   8
# 양천구 GS칼텍스     5   5
#     S-OIL     1   1
#     SK에너지     9   9
#     알뜰주유소     1   1
#     현대오일뱅크    9   9
# 은평구 GS칼텍스     6   6
#     S-OIL     2   2
#     SK에너지     5   5
#     자가상표      1   1
#     현대오일뱅크    3   3
# 종로구 GS칼텍스     2   2
#     S-OIL     2   2
#     SK에너지     3   3
#     현대오일뱅크    2   2

# %%
# 구별/상표별 주유소 갯수 계산후 by 값을 데이터로 변경(reset_index() 실행)
oildf2.groupby(["구", "상표"], as_index=False)["휘발유"].count()
# Out:
#       구      상표  휘발유
# 0   강남구   GS칼텍스    9
# 1   강남구   SK에너지   15
# 2   강남구    SOIL    5
# 3   강남구  현대오일뱅크    8
# 4   강동구   GS칼텍스    5
# 5   강동구   S-OIL    2
# 6   강동구   SK에너지    3
# 7   강동구  현대오일뱅크    4
# 8   강북구   GS칼텍스    3
# 9   강북구   S-OIL    3
# 10  강북구   SK에너지    3
# 11  강북구  현대오일뱅크    4
# 12  노원구   GS칼텍스    6
# 13  노원구   S-OIL    3
# 14  노원구   SK에너지    3
# 15  노원구  현대오일뱅크    3
# 16  도봉구   GS칼텍스    3
# 17  도봉구   S-OIL    5
# 18  도봉구   SK에너지    3
# 19  도봉구  현대오일뱅크    7
# 20  마포구   GS칼텍스    1
# 21  마포구   S-OIL    3
# 22  마포구   SK에너지    5
# 23  마포구  현대오일뱅크    3
# 24  서초구   GS칼텍스   13
# 25  서초구   S-OIL    5
# 26  서초구   SK에너지    9
# 27  서초구  알뜰(ex)    1
# 28  서초구  현대오일뱅크    5
# 29  송파구   GS칼텍스    9
# 30  송파구   S-OIL    5
# 31  송파구   SK에너지   10
# 32  송파구  현대오일뱅크    8
# 33  양천구   GS칼텍스    5
# 34  양천구   S-OIL    1
# 35  양천구   SK에너지    9
# 36  양천구   알뜰주유소    1
# 37  양천구  현대오일뱅크    9
# 38  은평구   GS칼텍스    6
# 39  은평구   S-OIL    2
# 40  은평구   SK에너지    5
# 41  은평구    자가상표    1
# 42  은평구  현대오일뱅크    3
# 43  종로구   GS칼텍스    2
# 44  종로구   S-OIL    2
# 45  종로구   SK에너지    3
# 46  종로구  현대오일뱅크    2

# %%
# 그룹 안에서 원한는 데이터 확인
oildf2.groupby("구").get_group("노원구")
# Out:
#                     상호      상표    구 셀프여부     휘발유      경유
# 180              한신주유소   SK에너지  노원구    Y  1968.0  1838.0
# 181              삼육주유소   SK에너지  노원구    Y  1975.0  1845.0
# 182            태릉솔밭주유소   S-OIL  노원구    Y  1995.0  1895.0
# 183             화랑대주유소  현대오일뱅크  노원구    Y  1995.0  1895.0
# 184     이엠석유(주)배꽃나라주유소   GS칼텍스  노원구    Y  2009.0  1909.0
# 185    현대오일뱅크㈜직영 하계주유소  현대오일뱅크  노원구    N  2015.0  1925.0
# 186              월계주유소   GS칼텍스  노원구    Y  2015.0  1915.0
# 187     SK에너지㈜직영 상계주유소   SK에너지  노원구    N  2025.0  1965.0
# 188   남선석유(주)구도일주유소 불암   S-OIL  노원구    Y  2025.0  1965.0
# 189              노원주유소   GS칼텍스  노원구    N  2038.0  1949.0
# 190             상계동주유소  현대오일뱅크  노원구    N  2090.0  1990.0
# 191            하계삼호주유소   GS칼텍스  노원구    N  2095.0  1995.0
# 192             성북역주유소   GS칼텍스  노원구    N  2098.0  1998.0
# 193  (주)소모에너지 수락산셀프주유소   GS칼텍스  노원구    Y  2098.0  1998.0
# 194              신성주유소   S-OIL  노원구    Y  2098.0  1998.0

# %%
# oildf2 csv 파일로 저장하기
oildf2.to_csv("서울시유류정보_0314.csv", index=False, encoding="cp949")

# %%
# 코랩에서 저장한 파일 다운로드
from google.colab import files

files.download("서울시유류정보_0314.csv")
