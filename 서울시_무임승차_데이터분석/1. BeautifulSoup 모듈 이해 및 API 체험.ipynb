# %% [markdown]
# # 구글맵 API 체험
# - 구글맵 API 가입
# - 참고: https://cloud.google.com/maps-platform/
# - 참고: https://tinyurl.com/y3uw2ppf

# %%
# !pip install googlemaps
# Out:
# Requirement already satisfied: googlemaps in /Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages (4.6.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages (from googlemaps) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)

# %%
# !pip install googlemaps
import googlemaps  # 제공 데이터는 Json 형식으로 제공

user_Key='AIzaSyB8Ua6RAi-ZC5WoE4xbEtlnEWZ_XOpaWGk'
gmaps=googlemaps.Client(key=user_Key)

sch = input("조회할 상호/명칭을 입력하세요:")
ggmp = gmaps. geocode(sch, language = 'ko')
ggmp
# Out:
# 조회할 상호/명칭을 입력하세요:강동
# [{'address_components': [{'long_name': '강동구',
#     'short_name': '강동구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 강동구',
#   'geometry': {'bounds': {'northeast': {'lat': 37.5817974, 'lng': 127.1835899},
#     'southwest': {'lat': 37.5168014, 'lng': 127.109265}},
#    'location': {'lat': 37.5301251, 'lng': 127.123762},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 37.5817974, 'lng': 127.1835899},
#     'southwest': {'lat': 37.5168014, 'lng': 127.109265}}},
#   'place_id': 'ChIJOVvKgxWwfDURiyyT9sq7aX4',
#   'types': ['political', 'sublocality', 'sublocality_level_1']}]

# %%
ggmp[0]
# Out:
# {'address_components': [{'long_name': '강동구',
#    'short_name': '강동구',
#    'types': ['political', 'sublocality', 'sublocality_level_1']},
#   {'long_name': '서울특별시',
#    'short_name': '서울특별시',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': '대한민국',
#    'short_name': 'KR',
#    'types': ['country', 'political']}],
#  'formatted_address': '대한민국 서울특별시 강동구',
#  'geometry': {'bounds': {'northeast': {'lat': 37.5817974, 'lng': 127.1835899},
#    'southwest': {'lat': 37.5168014, 'lng': 127.109265}},
#   'location': {'lat': 37.5301251, 'lng': 127.123762},
#   'location_type': 'APPROXIMATE',
#   'viewport': {'northeast': {'lat': 37.5817974, 'lng': 127.1835899},
#    'southwest': {'lat': 37.5168014, 'lng': 127.109265}}},
#  'place_id': 'ChIJOVvKgxWwfDURiyyT9sq7aX4',
#  'types': ['political', 'sublocality', 'sublocality_level_1']}

# %%
print("주소:", ggmp[0]['formatted_address'])
print(ggmp[0]['geometry'])
print()
print(ggmp[0]['geometry']['location'])
print()
print(ggmp[0]['geometry']['location']['lat'])
print(ggmp[0]['geometry']['location']['lng'])
# Out:
# 주소: 대한민국 서울특별시 강동구
# {'bounds': {'northeast': {'lat': 37.5817974, 'lng': 127.1835899}, 'southwest': {'lat': 37.5168014, 'lng': 127.109265}}, 'location': {'lat': 37.5301251, 'lng': 127.123762}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 37.5817974, 'lng': 127.1835899}, 'southwest': {'lat': 37.5168014, 'lng': 127.109265}}}
#
# {'lat': 37.5301251, 'lng': 127.123762}
#
# 37.5301251
# 127.123762

# %% [markdown]
# 유가정보를 이용한 지도 그리기

# %%
# !pip install folium
# !pip install xlrd

# %%
import pandas as pd
import folium
import googlemaps
from glob import glob

# 해당위치의 폴더에서 원하는 파일만 추출해 리스트로 제공
filenames = glob("./data/*주유소*.xls")

df = pd.DataFrame()

for fname in filenames:
    tmp = pd.read_excel(fname, header = 2)
    df = pd.concat([df, tmp])
    
df = df.reset_index(drop = True)

# %%
df
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시         지에스칼텍스㈜ 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 3   서울특별시       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 4   서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# ..    ...                   ...                           ...     ...
# 71  서울특별시              (주)만정에너지         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
# 72  서울특별시               제이제이주유소                서울 강남구 언주로 716  현대오일뱅크
# 73  서울특별시                 삼성주유소          서울 강남구 삼성로 521 (삼성동)   SK에너지
# 74  서울특별시                 동우주유소     서울특별시 강남구  봉은사로 311 (논현동)   SK에너지
# 75  서울특별시                 경원주유소         서울 강남구 도산대로 428 (청담동)   S-OIL
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    02-487-2030    Y     -  2032  1942     -
# 1    02-441-0536    N     -  2033  1927     -
# 2    02-475-2600    N  2185  2035  1945  1500
# 3    02-484-1162    Y     -  2058  1958     -
# 4   02-3428-1739    Y  2200  2063  1999     -
# ..           ...  ...   ...   ...   ...   ...
# 71   02-518-5141    N  2748  2498  2314  1799
# 72   02-518-5631    N  2715  2545  2335     -
# 73   02-538-0809    N     -     -     -     -
# 74   02-542-6726    N     -     -     -     -
# 75   02-517-1957    N     -     -     -     -
#
# [76 rows x 10 columns]

# %%
mapdf = df[["상호", "주소", "상표", "휘발유"]]
mapdf.head()
# Out:
#                      상호                            주소      상표   휘발유
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크  2032
# 1                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크  2033
# 2         지에스칼텍스㈜ 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스  2035
# 3       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL  2058
# 4     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크  2063

# %%
# 주소에서 ()에 있는 데이터 제거
for i in mapdf.index:
    mapdf.loc[i,"주소"] = mapdf.loc[i,"주소"].split("(")[0]
mapdf.head()
# Out:
# /var/folders/rt/5jvyxhl160n0wkcqnqvygf8m0000gn/T/ipykernel_25872/84413997.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf.loc[i,"주소"] = mapdf.loc[i,"주소"].split("(")[0]
#                      상호                     주소      상표   휘발유
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246   현대오일뱅크  2032
# 1                구천면주유소       서울 강동구 구천면로 357   현대오일뱅크  2033
# 2         지에스칼텍스㈜ 신월주유소      서울 강동구 양재대로 1323    GS칼텍스  2035
# 3       (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556    S-OIL  2058
# 4     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로 168   현대오일뱅크  2063

# %%
# 구글 API를 이용한 주소 검색 (위도/경도 추출)
user_Key='AIzaSyB8Ua6RAi-ZC5WoE4xbEtlnEWZ_XOpaWGk'
gmaps=googlemaps.Client(key=user_Key)

lat = []; lng = []

for i in mapdf.index:
    ggmap = gmaps.geocode(mapdf.loc[i, "주소"], language = 'ko')
lat = ggmap[-1]['geometry']['location']['lat']
lng = ggmap[-1]['geometry']['location']['lng']

# %%
# mapdf의 주소를 이용해 위도/경도 필드 추가

ggmap = gmaps.geocode("서울 양천구 신정로 236", language = 'ko')
lat = ggmap[-1]['geometry']['location']['lat']
lng = ggmap[-1]['geometry']['location']['lng']

mapdf['위도'] = lat
mapdf['경도'] = lng
mapdf.head()
# Out:
# /var/folders/rt/5jvyxhl160n0wkcqnqvygf8m0000gn/T/ipykernel_25872/2162310258.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf['위도'] = lat
# /var/folders/rt/5jvyxhl160n0wkcqnqvygf8m0000gn/T/ipykernel_25872/2162310258.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf['경도'] = lng
#                      상호                     주소      상표   휘발유         위도  \
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246   현대오일뱅크  2032  37.510518
# 1                구천면주유소       서울 강동구 구천면로 357   현대오일뱅크  2033  37.510518
# 2         지에스칼텍스㈜ 신월주유소      서울 강동구 양재대로 1323    GS칼텍스  2035  37.510518
# 3       (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556    S-OIL  2058  37.510518
# 4     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로 168   현대오일뱅크  2063  37.510518
#
#            경도
# 0  126.847688
# 1  126.847688
# 2  126.847688
# 3  126.847688
# 4  126.847688

# %%
m = folium.Map(location =[37.5373614,127.1244733], zoom_start = 17)
folium.Marker([mapdf.loc[75, "위도"], mapdf.loc[75, "경도"]], 
              popup = mapdf.loc[0, "상호"], 
              icon = folium.Icon(color = 'red')).add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5e6e2826e8064c39a2af58be462a8c99%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5e6e2826e8064c39a2af58be462a8c99%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5e6e2826e8064c39a2af58be462a8c99%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5e6e2826e8064c39a2af58be462a8c99%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5373614%2C%20127.1244733%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
